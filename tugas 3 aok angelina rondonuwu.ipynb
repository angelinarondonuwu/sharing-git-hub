# %% [raw]
# # masukan library yang akan kita gunakan
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # melakukan pembacaan pada dataset dalam format
# data = pd.read_excel('Data.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
# Data Responden                                                                  5 non-null object
# Bisakah anda membedakan ms office dengan libre office?                          5 non-null int64
# Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?    5 non-null int64
# Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?                 5 non-null int64
# Apakah bisa menggunakan simbol matematika di microsoft excel?                   5 non-null int64
# Apakah microsoft office sangat menunjang pendidikan di kampus?                  5 non-null int64
# Apakah anda sering menggunakan microsoft office?                                5 non-null int64
# Seberapa familiar anda menggunakan ms office?                                   5 non-null int64
# Bisakah anda membedakan antara file docx dan odt?                               5 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 432.0+ bytes

# %%
# print 10 data pertama dalam tabel (validasi input)
data.head(10)
# Out:
#         Data Responden  \
# 0        Sangat Setuju
# 1               Setuju
# 2          Ragu - Ragu
# 3         Tidak Setuju
# 4  Sangat Tidak Setuju
#
#    Bisakah anda membedakan ms office dengan libre office?  \
# 0                                                125
# 1                                                187
# 2                                                145
# 3                                                 33
# 4                                                 10
#
#    Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?  \
# 0                                                 80
# 1                                                167
# 2                                                176
# 3                                                 56
# 4                                                 23
#
#    Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?  \
# 0                                                330
# 1                                                125
# 2                                                 25
# 3                                                 18
# 4                                                  4
#
#    Apakah bisa menggunakan simbol matematika di microsoft excel?  \
# 0                                                255
# 1                                                148
# 2                                                 59
# 3                                                 19
# 4                                                 15
#
#    Apakah microsoft office sangat menunjang pendidikan di kampus?  \
# 0                                                354
# 1                                                106
# 2                                                 21
# 3                                                 10
# 4                                                  6
#
#    Apakah anda sering menggunakan microsoft office?  \
# 0                                               301
# 1                                               133
# 2                                                43
# 3                                                12
# 4                                                 8
#
#    Seberapa familiar anda menggunakan ms office?  \
# 0                                            255
# 1                                            171
# 2                                             45
# 3                                             18
# 4                                              7
#
#    Bisakah anda membedakan antara file docx dan odt?
# 0                                                123
# 1                                                161
# 2                                                147
# 3                                                 45
# 4                                                 18

# %%
# melihat 5 data terakhir yang dimiliki
data.tail()
# Out:
#         Data Responden  \
# 0        Sangat Setuju
# 1               Setuju
# 2          Ragu - Ragu
# 3         Tidak Setuju
# 4  Sangat Tidak Setuju
#
#    Bisakah anda membedakan ms office dengan libre office?  \
# 0                                                125
# 1                                                187
# 2                                                145
# 3                                                 33
# 4                                                 10
#
#    Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?  \
# 0                                                 80
# 1                                                167
# 2                                                176
# 3                                                 56
# 4                                                 23
#
#    Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?  \
# 0                                                330
# 1                                                125
# 2                                                 25
# 3                                                 18
# 4                                                  4
#
#    Apakah bisa menggunakan simbol matematika di microsoft excel?  \
# 0                                                255
# 1                                                148
# 2                                                 59
# 3                                                 19
# 4                                                 15
#
#    Apakah microsoft office sangat menunjang pendidikan di kampus?  \
# 0                                                354
# 1                                                106
# 2                                                 21
# 3                                                 10
# 4                                                  6
#
#    Apakah anda sering menggunakan microsoft office?  \
# 0                                               301
# 1                                               133
# 2                                                43
# 3                                                12
# 4                                                 8
#
#    Seberapa familiar anda menggunakan ms office?  \
# 0                                            255
# 1                                            171
# 2                                             45
# 3                                             18
# 4                                              7
#
#    Bisakah anda membedakan antara file docx dan odt?
# 0                                                123
# 1                                                161
# 2                                                147
# 3                                                 45
# 4                                                 18

# %%
# melihat dimensi data
data.shape
# Out:
# (5, 9)

# %%
# melihat feature apa saja yang dimiliki
data.columns
# Out:
# Index([u'Data Responden',
#        u'Bisakah anda membedakan ms office dengan libre office?',
#        u'Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?',
#        u'Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?',
#        u'Apakah bisa menggunakan simbol matematika di microsoft excel?',
#        u'Apakah microsoft office sangat menunjang pendidikan di kampus?',
#        u'Apakah anda sering menggunakan microsoft office?',
#        u'Seberapa familiar anda menggunakan ms office?',
#        u'Bisakah anda membedakan antara file docx dan odt?'],
#       dtype='object')

# %%
# deskripsi data
data.describe()
# Out:
#        Bisakah anda membedakan ms office dengan libre office?  \
# count                                           5.000000
# mean                                          100.000000
# std                                            75.511589
# min                                            10.000000
# 25%                                            33.000000
# 50%                                           125.000000
# 75%                                           145.000000
# max                                           187.000000
#
#        Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?  \
# count                                           5.000000
# mean                                          100.400000
# std                                            68.061002
# min                                            23.000000
# 25%                                            56.000000
# 50%                                            80.000000
# 75%                                           167.000000
# max                                           176.000000
#
#        Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?  \
# count                                           5.000000
# mean                                          100.400000
# std                                           137.012043
# min                                             4.000000
# 25%                                            18.000000
# 50%                                            25.000000
# 75%                                           125.000000
# max                                           330.000000
#
#        Apakah bisa menggunakan simbol matematika di microsoft excel?  \
# count                                           5.000000
# mean                                           99.200000
# std                                           102.216437
# min                                            15.000000
# 25%                                            19.000000
# 50%                                            59.000000
# 75%                                           148.000000
# max                                           255.000000
#
#        Apakah microsoft office sangat menunjang pendidikan di kampus?  \
# count                                           5.000000
# mean                                           99.400000
# std                                           148.093889
# min                                             6.000000
# 25%                                            10.000000
# 50%                                            21.000000
# 75%                                           106.000000
# max                                           354.000000
#
#        Apakah anda sering menggunakan microsoft office?  \
# count                                          5.000000
# mean                                          99.400000
# std                                          123.435408
# min                                            8.000000
# 25%                                           12.000000
# 50%                                           43.000000
# 75%                                          133.000000
# max                                          301.000000
#
#        Seberapa familiar anda menggunakan ms office?  \
# count                                       5.000000
# mean                                       99.200000
# std                                       108.927499
# min                                         7.000000
# 25%                                        18.000000
# 50%                                        45.000000
# 75%                                       171.000000
# max                                       255.000000
#
#        Bisakah anda membedakan antara file docx dan odt?
# count                                           5.000000
# mean                                           98.800000
# std                                            63.641182
# min                                            18.000000
# 25%                                            45.000000
# 50%                                           123.000000
# 75%                                           147.000000
# max                                           161.000000

# %%
# lihat korelasi antara features
# tapi, correlation does not imply causation
# if then are both above their mean (or both below),
# then this will produce a positive number,
# because a positivexpositive=positive, and likewise a
# negativexnegative=positive

# min_periode : int, optional => minimum number of observations required

# correlations = data.corr() #default: pearson
# correlationa = data.corr(method='spearman',min_periods=1)
# correlations = data.corr(method='pearson',min_periods=1)
correlations = data.corr(method='kendall')
correlations
# Out:
#                                                     Bisakah anda membedakan ms office dengan libre office?  \
# Bisakah anda membedakan ms office dengan libre ...                                                1.0
# Mampukah anda membuat laporan (dokumen/presenta...                                                0.8
# Menurut anda Microsoft powerpoint bisa memasukk...                                                0.6
# Apakah bisa menggunakan simbol matematika di mi...                                                0.6
# Apakah microsoft office sangat menunjang pendid...                                                0.6
# Apakah anda sering menggunakan microsoft office?                                                  0.6
# Seberapa familiar anda menggunakan ms office?                                                     0.6
# Bisakah anda membedakan antara file docx dan odt?                                                 1.0
#
#                                                     Mampukah anda membuat laporan (dokumen/presentasi) menggunakan libre office?  \
# Bisakah anda membedakan ms office dengan libre ...                                                0.8
# Mampukah anda membuat laporan (dokumen/presenta...                                                1.0
# Menurut anda Microsoft powerpoint bisa memasukk...                                                0.4
# Apakah bisa menggunakan simbol matematika di mi...                                                0.4
# Apakah microsoft office sangat menunjang pendid...                                                0.4
# Apakah anda sering menggunakan microsoft office?                                                  0.4
# Seberapa familiar anda menggunakan ms office?                                                     0.4
# Bisakah anda membedakan antara file docx dan odt?                                                 0.8
#
#                                                     Menurut anda Microsoft powerpoint bisa memasukkan gambar/video?  \
# Bisakah anda membedakan ms office dengan libre ...                                                0.6
# Mampukah anda membuat laporan (dokumen/presenta...                                                0.4
# Menurut anda Microsoft powerpoint bisa memasukk...                                                1.0
# Apakah bisa menggunakan simbol matematika di mi...                                                1.0
# Apakah microsoft office sangat menunjang pendid...                                                1.0
# Apakah anda sering menggunakan microsoft office?                                                  1.0
# Seberapa familiar anda menggunakan ms office?                                                     1.0
# Bisakah anda membedakan antara file docx dan odt?                                                 0.6
#
#                                                     Apakah bisa menggunakan simbol matematika di microsoft excel?  \
# Bisakah anda membedakan ms office dengan libre ...                                                0.6
# Mampukah anda membuat laporan (dokumen/presenta...                                                0.4
# Menurut anda Microsoft powerpoint bisa memasukk...                                                1.0
# Apakah bisa menggunakan simbol matematika di mi...                                                1.0
# Apakah microsoft office sangat menunjang pendid...                                                1.0
# Apakah anda sering menggunakan microsoft office?                                                  1.0
# Seberapa familiar anda menggunakan ms office?                                                     1.0
# Bisakah anda membedakan antara file docx dan odt?                                                 0.6
#
#                                                     Apakah microsoft office sangat menunjang pendidikan di kampus?  \
# Bisakah anda membedakan ms office dengan libre ...                                                0.6
# Mampukah anda membuat laporan (dokumen/presenta...                                                0.4
# Menurut anda Microsoft powerpoint bisa memasukk...                                                1.0
# Apakah bisa menggunakan simbol matematika di mi...                                                1.0
# Apakah microsoft office sangat menunjang pendid...                                                1.0
# Apakah anda sering menggunakan microsoft office?                                                  1.0
# Seberapa familiar anda menggunakan ms office?                                                     1.0
# Bisakah anda membedakan antara file docx dan odt?                                                 0.6
#
#                                                     Apakah anda sering menggunakan microsoft office?  \
# Bisakah anda membedakan ms office dengan libre ...                                               0.6
# Mampukah anda membuat laporan (dokumen/presenta...                                               0.4
# Menurut anda Microsoft powerpoint bisa memasukk...                                               1.0
# Apakah bisa menggunakan simbol matematika di mi...                                               1.0
# Apakah microsoft office sangat menunjang pendid...                                               1.0
# Apakah anda sering menggunakan microsoft office?                                                 1.0
# Seberapa familiar anda menggunakan ms office?                                                    1.0
# Bisakah anda membedakan antara file docx dan odt?                                                0.6
#
#                                                     Seberapa familiar anda menggunakan ms office?  \
# Bisakah anda membedakan ms office dengan libre ...                                            0.6
# Mampukah anda membuat laporan (dokumen/presenta...                                            0.4
# Menurut anda Microsoft powerpoint bisa memasukk...                                            1.0
# Apakah bisa menggunakan simbol matematika di mi...                                            1.0
# Apakah microsoft office sangat menunjang pendid...                                            1.0
# Apakah anda sering menggunakan microsoft office?                                              1.0
# Seberapa familiar anda menggunakan ms office?                                                 1.0
# Bisakah anda membedakan antara file docx dan odt?                                             0.6
#
#                                                     Bisakah anda membedakan antara file docx dan odt?
# Bisakah anda membedakan ms office dengan libre ...                                                1.0
# Mampukah anda membuat laporan (dokumen/presenta...                                                0.8
# Menurut anda Microsoft powerpoint bisa memasukk...                                                0.6
# Apakah bisa menggunakan simbol matematika di mi...                                                0.6
# Apakah microsoft office sangat menunjang pendid...                                                0.6
# Apakah anda sering menggunakan microsoft office?                                                  0.6
# Seberapa familiar anda menggunakan ms office?                                                     0.6
# Bisakah anda membedakan antara file docx dan odt?                                                 1.0

# %%
# correlation map
# higher correlation are brighter
f,ax = plt.subplots(figsize=(20,20))
sns.heatmap(correlations, annot=True, linewidths=.5, fmt='.3f',
ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show>
